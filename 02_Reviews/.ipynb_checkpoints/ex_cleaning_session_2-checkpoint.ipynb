# %%
# Data manipulation
import numpy as np 
import pandas as pd 
import swifter
import functools
import operator

# Data Vis
import matplotlib.pyplot as plt
from PIL import Image

# Text manipulation
from string import punctuation
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer

# NLP Module
import nltk
nltk.download('punkt')
nltk.download('stopwords')

from nltk.corpus import stopwords
from nltk import word_tokenize,sent_tokenize
from nltk import WordNetLemmatizer

from nltk.stem.porter import *
from nltk.stem.lancaster import *
from nltk.stem.snowball import SnowballStemmer
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/antoinedemeire/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/antoinedemeire/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from pandas_profiling import ProfileReport

# %%
# Path of folders where data are stored
DATA_PATH = "data/"
FIG_PATH = "fig/"

# %% [markdown]
# # Hands ON 1

# %% [markdown]
# ## Load Data

# %%
# Try to name your data / dataframe explicitly. 
file_name = "raw_scrapped_data.csv.gzip"
file_path = DATA_PATH + file_name

# Reading data
scrapped_data = pd.read_csv(file_path, compression='gzip')

# %%
# scrapped_data = pd.read_json(DATA_PATH + "scrapped_data", lines=True)

# import json_lines
# json_data = []
# with open(DATA_PATH + "raw_review_london.jl", 'rb') as f:
#     reader = json_lines.reader(f)
#     for line in reader:
#         try:
#             json_data.append(line)
#         except:
#             pass
        
# scrapped_data = pd.DataFrame.from_records(json_data)
# print(scrapped_data.shape)

# %%
# Take only a limited number of our reviews to increase speed / reduce process time
# You may want to start with low number of rows to see if your code works, and then increase this number to perform
# relevant and global analysis

# With sample you can specify a raw value of number of rows you want 
# scrapped_data = scrapped_data.sample(30000)

# Or you can specify a fraction of initial rows
# scrapped_data = scrapped_data.sample(frac=0.1)

# %% [markdown]
# ## Explore Data

# %%
scrapped_data.sample()
# Out:
#               id_resto                  id_comment            resto  \
# 23971  g186338-d720797  g186338-d720797-r212364539  The_Savoy_Grill
#
#                                                resto_url  rating     title  \
# 23971  /Restaurant_Review-g186338-d720797-Reviews-The...       5  Nice Day
#
#       diner_date    rating_date answer_text reviewer_pseudo reviewer_origin  \
# 23971   May 2014  June 27, 2014         NaN       583barryc              []
#
#                                       reviewer_info_sup  \
# 23971  [['pencil-paper', '6'], ['thumbs-up-fill', '7']]
#
#                            other_ratings_category       other_ratings_value  \
# 23971  ['Value', 'Atmosphere', 'Service', 'Food']  ['50', '50', '50', '50']
#
#                                                      url  \
# 23971  https://www.tripadvisor.com/ShowUserReviews-g1...
#
#                                                  content
# 23971  ['It was my 73rd birthday,and my Daughter trea...

# %% [markdown]
# ## Feature Engineering

# %%
# Create useful columns/features
data = pd.DataFrame()

# %%
data['day_of_week'] = pd.to_datetime(scrapped_data['rating_date']).dt.weekday

# %%
data['len_review'] = scrapped_data.content.apply(len)

# %%
data['content'] = scrapped_data.content

# %%
data['content'] = scrapped_data['content'].apply(lambda x: "".join(x))

# %%
data['rating'] = scrapped_data.rating

# %%
data.head()
# Out:
#    day_of_week  len_review                                            content  \
# 0            0         634  ['Decided to visit Windsor castle on the way b...
# 1            6         185  ['The food was very good (although rather smal...
# 2            2         784  ['When looking for somewhere in budget to go a...
# 3            3         401  ['Good menu selection. Unfortunately had no st...
# 4            5         392  ['We popped in here last night for a glass of ...
#
#    rating
# 0       5
# 1       2
# 2       5
# 3       4
# 4       3

# %% [markdown]
# ## Some visualisations

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import wordcloud

sns.set(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})

# %%
# What do you want to observe quickly ?

# %%
## Review Length Distribution
fig, axs = plt.subplots(figsize=(10,5))
sns.distplot(data.len_review);
axs.set_title('Review Length Distribution');


## Review Length Distribution (w.r.t. rating)
# Initialize the FacetGrid object
pal = sns.cubehelix_palette(5, rot=-.25, light=.6)
g = sns.FacetGrid(data[data.len_review<4000], row="rating", hue="rating", aspect=9.5, height=1, palette=pal)

# Draw the densities in a few steps
g.map(sns.kdeplot, "len_review", clip_on=False, shade=True, alpha=1, lw=1.5, bw=.2)
g.map(sns.kdeplot, "len_review", clip_on=False, color="w", lw=2, bw=.2)
g.map(plt.axhline, y=0, lw=2, clip_on=False)


# Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .2, label, fontweight="bold", fontsize=20, color=color, ha="left", va="center", transform=ax.transAxes)
g.map(label, "len_review")

# Set the subplots to overlap
g.fig.subplots_adjust(hspace = -0.375)

# Remove axes details that don't play well with overlap
g.set_titles("")
g.set(yticks=[])
g.despine(bottom=True, left=True);

# %% [markdown]
# ## Work on reviews

# %% [markdown]
# ### Preprocessing

# %%
reviews = data['content'].tolist()

# %%
reviews[42]
# Out:
# "['Hard to believe but London has good food these days. We rented an apt. and the owners recommended the Cote Bistro in Covent Garden (we also ate at a branch in Kensington and Soho). The food was just outstanding, service was fine (mostly young people from out of the country). Highly recommend any of these which they say are less than three years old. Recommend you look at daily specials. We had a Rib Eye steak for two that was outstanding, as was the Sea Bass, or their standard chicken dinner. So glad to be able to recommend them.']"

# %%
###########################
#   Homework function 1   #
###########################

def basic_cleaning(rev, stemming="porter"):
    """
    NOTE:
    """
    # Normalize case & Remove punctuation
    rev = "".join([c for c in rev if c not in punctuation]).lower()
    # Tokenize review
    rev = word_tokenize(rev)
    # Remove Stopwords
    rev = [w for w in rev if not w in set(stopwords.words('english'))]
    # Lemmatize Review
    stemmer = {"porter": PorterStemmer(), 
                   "snowball": SnowballStemmer("english"), 
                   "lancaster": LancasterStemmer()}
    try:
        rev = [stemmer[stemming].stem(wd) for wd in rev]
        return rev
    
    except:
        return rev

# %%
basic_cleaning(reviews[42])
# Out:
# ['hard',
#  'believ',
#  'london',
#  'good',
#  'food',
#  'day',
#  'rent',
#  'apt',
#  'owner',
#  'recommend',
#  'cote',
#  'bistro',
#  'covent',
#  'garden',
#  'also',
#  'ate',
#  'branch',
#  'kensington',
#  'soho',
#  'food',
#  'outstand',
#  'servic',
#  'fine',
#  'mostli',
#  'young',
#  'peopl',
#  'countri',
#  'highli',
#  'recommend',
#  'say',
#  'less',
#  'three',
#  'year',
#  'old',
#  'recommend',
#  'look',
#  'daili',
#  'special',
#  'rib',
#  'eye',
#  'steak',
#  'two',
#  'outstand',
#  'sea',
#  'bass',
#  'standard',
#  'chicken',
#  'dinner',
#  'glad',
#  'abl',
#  'recommend']

# %%
data['content'] = data['content'].apply(basic_cleaning)

# %%
data.to_csv('data/reviews_processed.csv')

# %% [markdown]
# ## Function from corpus to wordcloud

# %%
###########################
#   Homework function 2   #
###########################
def from_corpus_to_word_cloud(reviews, fig=None):
    """
    NOTE: 
    """
    ## Flattened List from Cleaned Corpus
    reviews = functools.reduce(operator.iconcat, reviews.tolist(), [])
    ## Stopwords
    swords = ['restaur']
    ## Generate WordCloud
    try:
        im_mask =np.array(Image.open(FIG_PATH + fig))
        wcloud = WordCloud(width = 1000, height = 500, stopwords=swords, mask=im_mask)
    except:
        wcloud = WordCloud(width = 1000, height = 500, stopwords=swords)
        
        
    wordcloud = wcloud.generate((" ").join(reviews))
    plt.figure(figsize=(15,8))
    plt.imshow(wordcloud)
    plt.axis("off")
    plt.show()
    plt.close()
    return

# %%
from_corpus_to_word_cloud(data[data.rating==5].content,fig='pos.png')

# %%
from_corpus_to_word_cloud(data[data.rating==1].content,fig='neg.png')

# %% [markdown]
# # Homeworks

# %% [markdown]
# For homework you are asked to code 2 functions :
# - A function that do the basic cleaning of a corpus
# - A function that creates a wordcloud from a cleaned corpus
#
# Bonus : Be creative about text visualisations, and on how to get relevant insights from your reviews
